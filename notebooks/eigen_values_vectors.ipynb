# %%
import numpy as np
from scipy.linalg import eig, inv

# Define the matrix
A = np.array([[4, -5],
              [2, -3]])

# Compute eigenvalues and eigenvectors
eigenvalues, eigenvectors = eig(A) 

# Form the diagonal matrix
Lambda = np.diag(eigenvalues)

# Reconstruct A using A = S Λ S⁻¹
A_reconstructed = eigenvectors @ Lambda @ inv(eigenvectors)

# Display results
print("Original matrix A:\n", A)
print("\nEigenvalues:\n", eigenvalues)
print("\nEigenvectors (columns):\n", eigenvectors)
print("\nReconstructed matrix A:\n", A_reconstructed)
# Out:
# Original matrix A:
#  [[ 4 -5]
#  [ 2 -3]]
#
# Eigenvalues:
#  [ 2.+0.j -1.+0.j]
#
# Eigenvectors (columns):
#  [[0.92847669 0.70710678]
#  [0.37139068 0.70710678]]
#
# Reconstructed matrix A:
#  [[ 4.+0.j -5.+0.j]
#  [ 2.+0.j -3.+0.j]]
